# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.naive_bayes import CategoricalNB
from sklearn.metrics import accuracy_score
df=pd.read_csv("species.csv")
print(df)
def fun_naive_bayes_classification():
    x=df.drop('species',axis=1)
    y=df['species']
    
    encoder= OrdinalEncoder(handle_unknown='use_encoded_value',unknown_value=-1)
    x_encoded=encoder.fit_transform(x)
    
    x_train,x_test,y_train,y_test=train_test_split(x_encoded,y,test_size=0.2,random_state=50)
    
    model=CategoricalNB(alpha=1.0)
    model.fit(x_train,y_train)
    
    y_pred= model.predict(x_test)
    print(f"model Accuracy:{accuracy_score(y_test,y_pred) * 100:.2f}%")
    
    new_data = pd.DataFrame([['white', 'three', 'short', 'yes']],columns=['colour','legs','height','smelly'])
    

    new_encoded = encoder.transform(new_data)
    prediction = model.predict(new_encoded)

    print("Prediction for new data:", prediction[0])
# Out:
#   colour   legs height smelly species
# 0  white  three  short    yes       M
# 1  green    two   tall     no       M
# 2  green  three  short    yes       M
# 3  white  three  short    yes       M
# 4  green    two  short     no       H
# 5  white    two   tall     no       H
# 6  white    two   tall     no       H
# 7  white    two  short    yes       H

# %%
fun_naive_bayes_classification()
# Out:
# model Accuracy:50.00%
# Prediction for new data: M

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.naive_bayes import CategoricalNB
from sklearn.metrics import accuracy_score

df = pd.read_csv("species.csv")
print(df)

def fun_naive_bayes_classification():
    X = df.drop('species', axis=1)
    y = df['species']

    encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
    X_encoded = encoder.fit_transform(X)

    X_train, X_test, y_train, y_test = train_test_split(
        X_encoded, y, test_size=0.2, random_state=50
    )

    model = CategoricalNB(alpha=1.0)
    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)
    print(f"Model Accuracy: {accuracy_score(y_test, y_pred) * 100:.2f}%")

    # New data
    new_data = pd.DataFrame(
        [['white', 'three', 'short', 'yes']],
        columns=['color', 'legs', 'height', 'smelly']
    )

    new_encoded = encoder.transform(new_data)

    # Prediction
    predicted_species = model.predict(new_encoded)[0]
    probabilities = model.predict_proba(new_encoded)[0]

    print("\nNew Data:", new_data.iloc[0].to_dict())
    print("Predicted Species:", predicted_species)

    print("\nPrediction Probabilities:")
    for species, prob in zip(model.classes_, probabilities):
        print(f"{species}: {prob:.4f}")

fun_naive_bayes_classification()
# Out:
#   colour   legs height smelly species
# 0  white  three  short    yes       M
# 1  green    two   tall     no       M
# 2  green  three  short    yes       M
# 3  white  three  short    yes       M
# 4  green    two  short     no       H
# 5  white    two   tall     no       H
# 6  white    two   tall     no       H
# 7  white    two  short    yes       H
# Model Accuracy: 50.00%
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 47
#      44     for species, prob in zip(model.classes_, probabilities):
#      45         print(f"{species}: {prob:.4f}")
# ---> 47 fun_naive_bayes_classification()
#
# Cell In[10], line 34, in fun_naive_bayes_classification()
#      28 # New data
#      29 new_data = pd.DataFrame(
#      30     [['white', 'three', 'short', 'yes']],
#      31     columns=['color', 'legs', 'height', 'smelly']
#      32 )
# ---> 34 new_encoded = encoder.transform(new_data)
#      36 # Prediction
#      37 predicted_species = model.predict(new_encoded)[0]
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:1597, in OrdinalEncoder.transform(self, X)
#    1583 """
#    1584 Transform X to ordinal codes.
#    1585
#    (...)   1594     Transformed input.
#    1595 """
#    1596 check_is_fitted(self, "categories_")
# -> 1597 X_int, X_mask = self._transform(
#    1598     X,
#    1599     handle_unknown=self.handle_unknown,
#    1600     ensure_all_finite="allow-nan",
#    1601     ignore_category_indices=self._missing_indices,
#    1602 )
#    1603 X_trans = X_int.astype(self.dtype, copy=False)
#    1605 for cat_idx, missing_idx in self._missing_indices.items():
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:201, in _BaseEncoder._transform(self, X, handle_unknown, ensure_all_finite, warn_on_unknown, ignore_category_indices)
#     190 def _transform(
#     191     self,
#     192     X,
#    (...)    196     ignore_category_indices=None,
#     197 ):
#     198     X_list, n_samples, n_features = self._check_X(
#     199         X, ensure_all_finite=ensure_all_finite
#     200     )
# --> 201     _check_feature_names(self, X, reset=False)
#     202     _check_n_features(self, X, reset=False)
#     204     X_int = np.zeros((n_samples, n_features), dtype=int)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2787, in _check_feature_names(estimator, X, reset)
#    2784 if not missing_names and not unexpected_names:
#    2785     message += "Feature names must be in the same order as they were in fit.\n"
# -> 2787 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - color
# Feature names seen at fit time, yet now missing:
# - colour
